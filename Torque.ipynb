# %% [markdown]
# # Torque

# %%
from utils.Engineer import *

# %%
1 Nm
# Out:
# 1 N·m

# %%
# Micronewton metre
10⁶ µN·m
# Out:
# 1000000 μN·m

# %%
# Millinewton metre
10³ mNm
# Out:
# 1000 mN·m

# %%
# Kilonewton metre
(10⁻³) kN·m
# Out:
# 0.001 kN·m

# %%
#Pound-force foot
0.74 ft lbf
# Out:
# 0.74 ft·lbf

# %%
#Pound-force inch
8.85 lbf·inch
# Out:
# 8.85 lbf·inch

# %%
#Ounce-force foot (ozf·ft)
11.8 ozf·ft
# Out:
# 11.8 ozf·ft

# %%
#Ounce-force inch (ozf·in)
141.61 ozf·inch
# Out:
# 141.61 ozf·inch

# %%
#Kilogram-force metre (kgf·m)
0.1 kgf·m
# Out:
# 0.1 kgf·m

# %%
#Kilopond metre (kp·m)
0.1 kp·m
# Out:
# 0.1 kp·m

# %%
#Gram-force centimetre (gf·cm)
10197.2 gf·cm
# Out:
# 10197.2 gf·cm

# %%
#Metre kilogram-force
0.1 m·kgf
# Out:
# 0.1 m·kgf

# %%
#Centimetre kilogram-force
10.2 cm kgf
# Out:
# 10.2 cm·kgf

# %%
#Inch ounce-force
141.61 inch ozf
# Out:
# 141.61 inch·ozf

# %%
#Dyne centimetre (dyn cm)
10⁷ dyne cm
# Out:
# 10000000 dyne·cm
